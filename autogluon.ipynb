# %%
from autogluon.multimodal import MultiModalPredictor
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train_cleaned.csv', keep_default_na=False)

# %%
predictor = MultiModalPredictor(label='Transported', path='autogluon', eval_metric='accuracy')
predictor.fit(data)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 123
# AutoMM starts to create your model. ✨
#
# - Model will be saved to "/content/autogluon".
#
# - Validation metric is "accuracy".
#
# - To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/autogluon
#     ```
#
# Enjoy your coffee, and let AutoMM do the job ☕☕☕ Learn more at https://auto.gluon.ai
# ...
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit None Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test_cleaned.csv', keep_default_na=False)

# preprocess test data
X_test = test.drop(['PassengerId'], axis=1)

# predict
y_pred = predictor.predict(X_test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission.csv', index=False)
# Out:
# Predicting: 0it [00:00, ?it/s]

# %%
data2 = pd.read_csv('train.csv')
predictor2 = MultiModalPredictor(label='Transported', path='autogluon3', eval_metric='accuracy')
predictor2.fit(data2)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 123
# AutoMM starts to create your model. ✨
#
# - Model will be saved to "/content/autogluon3".
#
# - Validation metric is "accuracy".
#
# - To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/autogluon3
#     ```
#
# Enjoy your coffee, and let AutoMM do the job ☕☕☕ Learn more at https://auto.gluon.ai
#
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit None Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test.csv')

# predict
y_pred = predictor2.predict(test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission2.csv', index=False)
# Out:
# Predicting: 0it [00:00, ?it/s]

# %%
data3 = pd.read_csv('train_cleaned_no_fillna.csv')
predictor3 = MultiModalPredictor(label='Transported', path='autogluon4', eval_metric='accuracy')
predictor3.fit(data3)
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 123
# AutoMM starts to create your model. ✨
#
# - Model will be saved to "/content/autogluon4".
#
# - Validation metric is "accuracy".
#
# - To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /content/autogluon4
#     ```
#
# Enjoy your coffee, and let AutoMM do the job ☕☕☕ Learn more at https://auto.gluon.ai
#
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit None Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test_cleaned_no_fillna.csv')

# predict
y_pred = predictor3.predict(test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission2.csv', index=False)
# Out:
# Predicting: 0it [00:00, ?it/s]

# %%
from autogluon.tabular import TabularPredictor

# %%
predictor4 = TabularPredictor(label='Transported', path='autogluon5', eval_metric='accuracy')
predictor4.fit(data3, hyperparameters='multimodal')
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "autogluon5/"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    8693
# Train Data Columns: 17
# Label Column: Transported
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [False, True]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = True, class 0 = False
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    14769.86 MB
# ...

# %%
predictor4.leaderboard(data3)
# Out:
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/autogluon5/models/MultiModalPredictor/automm_model/hf_text/config.json
# Model config ElectraConfig {
#   "_name_or_path": "/content/autogluon5/models/MultiModalPredictor/automm_model/hf_text",
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test_cleaned_no_fillna.csv')

# predict
y_pred = predictor4.predict(test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission3.csv', index=False)
# Out:
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/autogluon5/models/MultiModalPredictor/automm_model/hf_text/config.json
# Model config ElectraConfig {
#   "_name_or_path": "/content/autogluon5/models/MultiModalPredictor/automm_model/hf_text",
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
# ...

# %%
predictor5 = TabularPredictor(label='Transported', path='autogluon5', eval_metric='accuracy')
predictor5.fit(data3, presets='best_quality', num_gpus=4)
# Out:
# ...
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "autogluon5/"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    8693
# Train Data Columns: 17
# Label Column: Transported
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [False, True]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = True, class 0 = False
# Using Feature Generators to preprocess the data ...
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test_cleaned_no_fillna.csv')

# predict
y_pred = predictor4.predict(test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission3.csv', index=False)
# Out:
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file /content/autogluon5/models/MultiModalPredictor/automm_model/hf_text/config.json
# Model config ElectraConfig {
#   "_name_or_path": "/content/autogluon5/models/MultiModalPredictor/automm_model/hf_text",
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
# ...

# %%
data4 = pd.read_csv('train_cleaned_no_fillna_imputed.csv')

# %%
predictor7 = TabularPredictor(label='Transported', path='autogluon7', eval_metric='accuracy')
predictor7.fit(data4, presets='best_quality', num_gpus=1)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "autogluon7/"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Sat Dec 10 16:00:40 UTC 2022
# Train Data Rows:    8693
# Train Data Columns: 17
# Label Column: Transported
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [False, True]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = True, class 0 = False
# Using Feature Generators to preprocess the data ...
# ...

# %%
# predict on test data for Kaggle submission
test = pd.read_csv('test_cleaned_no_fillna_imputed.csv')

# predict
y_pred = predictor7.predict(test)

# create submission file
submission = pd.DataFrame({'PassengerId': test['PassengerId'], 'Transported': y_pred})
submission.to_csv('submission3.csv', index=False)

# %%
predictor8 = TabularPredictor(label='Transported', path='autogluon8', eval_metric='accuracy')
predictor8.fit(data4, presets='best_quality', hyperparameters='multimodal', num_gpus=1)
# run this
